# %%
import pandas as pd
import pyreadstat as pystat
import matplotlib.pyplot as plt
import seaborn as sns
import utility_fns as utils

# %% [markdown]
# # Importing the dataset (Student Context data of students at 8th grade in Ireland)

# %%
org_data = pd.read_spss("./data/orig/SPSS/bsgirlm8.sav")
org_data_copy = org_data.copy()

# %% [markdown]
# # Construction of Dataset

# %% [markdown]
# ## Setting up  a new focused data set

# %% [markdown]
# ### Adding Basic contextual variables(Gender, Language, Books at Home, Computers at Home, Shared_Computers, Background of Parents etc) - Categorical

# %%
columns = [ "BSBG01", "BSBG03", "BSBG04",
    "BSBG05A", "BSBG05B", "BSBG05C", "BSBG05D",
    "BSBG05E", "BSBG05F", "BSBG06A",
    "BSBG06B", "BSBG07",
    "BSBG08A", "BSBG08B"]
df = org_data_copy[columns]
rename_dict = {
    "BSBG01": "Gender_Student",
    "BSBG03": "Lang_Spoken_Home",
    "BSBG04": "Books_Home",
    "BSBG05A": "Own_Computer",
    "BSBG05B": "Shared_Computer",
    "BSBG05C": "Smartphone",
    "BSBG05D": "Internet_Access",
    "BSBG05E": "Study_Desk",
    "BSBG05F": "Own_Room",
    "BSBG06A": "ParentA_Edu_Level",
    "BSBG06B": "ParentB_Edu_Level",
    "BSBG07": "Education_Expectation",
    "BSBG08A": "ParentA_Born_Country",
    "BSBG08B": "ParentB_Born_Country"
}
df = df.rename(columns=rename_dict)
df.head()
# Out:
#   Gender_Student Lang_Spoken_Home                                  Books_Home  \
# 0           Girl        Sometimes  Enough to fill one bookcase (26–100 books)
# 1           Girl        Sometimes  Enough to fill one bookcase (26–100 books)
# 2           Girl    Almost always  Enough to fill one bookcase (26–100 books)
# 3           Girl           Always               None or very few (0–10 books)
# 4        <Other>    Almost always  Enough to fill one bookcase (26–100 books)
#
#   Own_Computer Shared_Computer Smartphone Internet_Access Study_Desk Own_Room  \
# 0          Yes             Yes        Yes             Yes        Yes      Yes
# 1          Yes             Yes        Yes             Yes        Yes      Yes
# 2          Yes              No        Yes             Yes        Yes      Yes
# 3          Yes             Yes        Yes             Yes        Yes      Yes
# 4          Yes             Yes        Yes             Yes        Yes      Yes
#
#                            ParentA_Edu_Level  \
# 0                               I don’t know
# 1                               I don’t know
# 2                               I don’t know
# 3  <Lower secondary education—ISCED Level 2>
# 4  <Upper secondary education—ISCED Level 3>
#
#                                 ParentB_Edu_Level  \
# 0                                    I don’t know
# 1                                    I don’t know
# 2                                    I don’t know
# 3       <Lower secondary education—ISCED Level 2>
# 4  <Short-cycle tertiary education—ISCED Level 5>
#
#                                Education_Expectation ParentA_Born_Country  \
# 0  Finish <Postgraduate degree: Master’s—ISCED Le...                   No
# 1  Finish <Postgraduate degree: Master’s—ISCED Le...                   No
# 2  Finish <Short-cycle tertiary education—ISCED L...                   No
# 3  Finish <Postgraduate degree: Master’s—ISCED Le...                  Yes
# 4  Finish <Postgraduate degree: Master’s—ISCED Le...                   No
#
#   ParentB_Born_Country
# 0                   No
# 1                   No
# 2                   No
# 3                  Yes
# 4                   No

# %% [markdown]
# ### Adding Scale variables of Plausible Values for each subject

# %%
scale_vars = [
    "BSSSCI01", "BSSSCI02", "BSSSCI03", "BSSSCI04", "BSSSCI05",
    "BSSBIO01", "BSSBIO02", "BSSBIO03", "BSSBIO04", "BSSBIO05",
    "BSSCHE01", "BSSCHE02", "BSSCHE03", "BSSCHE04", "BSSCHE05",
    "BSSPHY01", "BSSPHY02", "BSSPHY03", "BSSPHY04", "BSSPHY05",
    "BSSEAR01", "BSSEAR02", "BSSEAR03", "BSSEAR04", "BSSEAR05"
]
scale_var_dict = {
    "BSSSCI01": "1ST_PV_SCIENCE",
    "BSSSCI02": "2ND_PV_SCIENCE",
    "BSSSCI03": "3RD_PV_SCIENCE",
    "BSSSCI04": "4TH_PV_SCIENCE",
    "BSSSCI05": "5TH_PV_SCIENCE",
    "BSSBIO01": "1ST_PV_BIOLOGY",
    "BSSBIO02": "2ND_PV_BIOLOGY",
    "BSSBIO03": "3RD_PV_BIOLOGY",
    "BSSBIO04": "4TH_PV_BIOLOGY",
    "BSSBIO05": "5TH_PV_BIOLOGY",
    "BSSCHE01": "1ST_PV_CHEMISTRY",
    "BSSCHE02": "2ND_PV_CHEMISTRY",
    "BSSCHE03": "3RD_PV_CHEMISTRY",
    "BSSCHE04": "4TH_PV_CHEMISTRY",
    "BSSCHE05": "5TH_PV_CHEMISTRY",
    "BSSPHY01": "1ST_PV_PHYSICS",
    "BSSPHY02": "2ND_PV PHYSICS",
    "BSSPHY03": "3RD_PV_PHYSICS",
    "BSSPHY04": "4TH_PV_PHYSICS",
    "BSSPHY05": "5TH_PV_PHYSICS",
    "BSSEAR01": "1ST_PV_EARTH SCIENCE",
    "BSSEAR02": "2ND_PV_EARTH SCIENCE",
    "BSSEAR03": "3RD_PV_EARTH SCIENCE",
    "BSSEAR04": "4TH_PV_EARTH SCIENCE",
    "BSSEAR05": "5TH_PV_EARTH SCIENCE"
}

scale_variables = org_data_copy[scale_vars].rename(columns=scale_var_dict)
df = pd.concat([df, scale_variables], axis=1)

# %% [markdown]
# ### Adding remaining categorical variables - (Behavioural attributes including, dissorderly behaviour, bullying, likeness for subjects, confidence etc)

# %%
columns = [
    "BSBGHER", "BSBGSSB", "BSBGSB", "BSBGSLM", "BSBGICM", "BSBGDML",
    "BSBGSCM", "BSBGSVM", "BSBGSLS", "BSBGICS", "BSBGSCS", "BSBGSVS",
    "BSBGSLB", "BSBGICB", "BSBGSCB", "BSBGSLE", "BSBGICE", "BSBGSCE",
    "BSBGSLC", "BSBGICC", "BSBGSCC", "BSBGSLP", "BSBGICP", "BSBGSCP",
    "BSBGSEC", "BSBGDSL", "BSBGDBL", "BSBGDEL", "BSBGDCL", "BSBGDPL",
    "BSBGVEP"
]
behav_attr =  {
    "BSBGHER": "Home_Educational_Resources",
    "BSBGSSB": "Students_Sense_of_School_Belonging",
    "BSBGSB": "Student_Bullying",
    "BSBGSLM": "Students_Like_Learning_Mathematics",
    "BSBGICM": "Instructional_Clarity_in_Mathematics_Lessons",
    "BSBGDML": "Disorderly_Behavior_during_Math_Lessons",
    "BSBGSCM": "Students_Confident_in_Mathematics",
    "BSBGSVM": "Students_Value_Mathematics",
    "BSBGSLS": "Students_Like_Learning_Science",
    "BSBGICS": "Instructional_Clarity_in_Science_Lessons",
    "BSBGSCS": "Students_Confident_in_Science",
    "BSBGSVS": "Students_Value_Science",
    "BSBGSLB": "Students_Like_Learning_Biology",
    "BSBGICB": "Instructional_Clarity_in_Biology_Lessons",
    "BSBGSCB": "Students_Confident_in_Biology",
    "BSBGSLE": "Students_Like_Learning_Earth_Science",
    "BSBGICE": "Instructional_Clarity_in_Earth_Science_Lessons",
    "BSBGSCE": "Students_Confident_in_Earth_Science",
    "BSBGSLC": "Students_Like_Learning_Chemistry",
    "BSBGICC": "Instructional_Clarity_in_Chemistry_Lessons",
    "BSBGSCC": "Students_Confident_in_Chemistry",
    "BSBGSLP": "Students_Like_Learning_Physics",
    "BSBGICP": "Instructional_Clarity_in_Physics_Lessons",
    "BSBGSCP": "Students_Confident_in_Physics",
    "BSBGSEC": "Digital_Self_Efficacy",
    "BSBGDSL": "Disorderly_Behavior_during_Science_Lessons",
    "BSBGDBL": "Disorderly_Behavior_during_Biology_Lessons",
    "BSBGDEL": "Disorderly_Behavior_during_Earth_Science_Lessons",
    "BSBGDCL": "Disorderly_Behavior_during_Chemistry_Lessons",
    "BSBGDPL": "Disorderly_Behavior_during_Physics_Lessons",
    "BSBGVEP": "Students_Value_Environmental_Preservation"
}

behavioral_attributes = org_data_copy[columns]
behavioral_attributes = behavioral_attributes[columns].rename(columns=behav_attr)
df = pd.concat([df, behavioral_attributes], axis=1)

# %% [markdown]
# ## Removing Emptyl Attributes
# Some empty attributes are present in the datafeame, which needs to be dropped.

# %%
df = df.dropna(axis=1, how='all')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5090 entries, 0 to 5089
# Data columns (total 54 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Gender_Student                                5043 non-null   category
#  1   Lang_Spoken_Home                              5033 non-null   category
#  2   Books_Home                                    5034 non-null   category
#  3   Own_Computer                                  5011 non-null   category
#  4   Shared_Computer                               4960 non-null   category
#  5   Smartphone                                    5025 non-null   category
#  6   Internet_Access                               5025 non-null   category
#  7   Study_Desk                                    5027 non-null   category
#  8   Own_Room                                      5017 non-null   category
#  9   ParentA_Edu_Level                             4836 non-null   category
#  10  ParentB_Edu_Level                             4570 non-null   category
#  11  Education_Expectation                         4986 non-null   category
#  12  ParentA_Born_Country                          5019 non-null   category
#  13  ParentB_Born_Country                          4973 non-null   category
#  14  1ST_PV_SCIENCE                                5090 non-null   category
#  15  2ND_PV_SCIENCE                                5090 non-null   category
#  16  3RD_PV_SCIENCE                                5090 non-null   category
#  17  4TH_PV_SCIENCE                                5090 non-null   category
#  18  5TH_PV_SCIENCE                                5090 non-null   category
#  19  1ST_PV_BIOLOGY                                5090 non-null   category
#  20  2ND_PV_BIOLOGY                                5090 non-null   category
#  21  3RD_PV_BIOLOGY                                5090 non-null   category
#  22  4TH_PV_BIOLOGY                                5090 non-null   category
#  23  5TH_PV_BIOLOGY                                5090 non-null   category
#  24  1ST_PV_CHEMISTRY                              5090 non-null   category
#  25  2ND_PV_CHEMISTRY                              5090 non-null   category
#  26  3RD_PV_CHEMISTRY                              5090 non-null   category
#  27  4TH_PV_CHEMISTRY                              5090 non-null   category
#  28  5TH_PV_CHEMISTRY                              5090 non-null   category
#  29  1ST_PV_PHYSICS                                5090 non-null   category
#  30  2ND_PV PHYSICS                                5090 non-null   category
#  31  3RD_PV_PHYSICS                                5090 non-null   category
#  32  4TH_PV_PHYSICS                                5090 non-null   category
#  33  5TH_PV_PHYSICS                                5090 non-null   category
#  34  1ST_PV_EARTH SCIENCE                          5090 non-null   category
#  35  2ND_PV_EARTH SCIENCE                          5090 non-null   category
#  36  3RD_PV_EARTH SCIENCE                          5090 non-null   category
#  37  4TH_PV_EARTH SCIENCE                          5090 non-null   category
#  38  5TH_PV_EARTH SCIENCE                          5090 non-null   category
#  39  Home_Educational_Resources                    5021 non-null   category
#  40  Students_Sense_of_School_Belonging            5003 non-null   category
#  41  Student_Bullying                              4993 non-null   category
#  42  Students_Like_Learning_Mathematics            5015 non-null   category
#  43  Instructional_Clarity_in_Mathematics_Lessons  5000 non-null   category
#  44  Disorderly_Behavior_during_Math_Lessons       5000 non-null   category
#  45  Students_Confident_in_Mathematics             4955 non-null   category
#  46  Students_Value_Mathematics                    4963 non-null   category
#  47  Students_Like_Learning_Science                4625 non-null   category
#  48  Instructional_Clarity_in_Science_Lessons      4608 non-null   category
#  49  Students_Confident_in_Science                 4569 non-null   category
#  50  Students_Value_Science                        4581 non-null   category
#  51  Digital_Self_Efficacy                         4981 non-null   category
#  52  Disorderly_Behavior_during_Science_Lessons    4610 non-null   category
#  53  Students_Value_Environmental_Preservation     4986 non-null   category
# dtypes: category(54)
# memory usage: 4.6 MB

# %% [markdown]
# ###  Managing null rows
# Since scale attributes have no null rows, the null values for the categorical variables needed to be taken care of. In this analysis, null rows will be dropped fo an efficient EDA

# %%
df = df.dropna(axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3875 entries, 0 to 5089
# Data columns (total 54 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Gender_Student                                3875 non-null   category
#  1   Lang_Spoken_Home                              3875 non-null   category
#  2   Books_Home                                    3875 non-null   category
#  3   Own_Computer                                  3875 non-null   category
#  4   Shared_Computer                               3875 non-null   category
#  5   Smartphone                                    3875 non-null   category
#  6   Internet_Access                               3875 non-null   category
#  7   Study_Desk                                    3875 non-null   category
#  8   Own_Room                                      3875 non-null   category
#  9   ParentA_Edu_Level                             3875 non-null   category
#  10  ParentB_Edu_Level                             3875 non-null   category
#  11  Education_Expectation                         3875 non-null   category
#  12  ParentA_Born_Country                          3875 non-null   category
#  13  ParentB_Born_Country                          3875 non-null   category
#  14  1ST_PV_SCIENCE                                3875 non-null   category
#  15  2ND_PV_SCIENCE                                3875 non-null   category
#  16  3RD_PV_SCIENCE                                3875 non-null   category
#  17  4TH_PV_SCIENCE                                3875 non-null   category
#  18  5TH_PV_SCIENCE                                3875 non-null   category
#  19  1ST_PV_BIOLOGY                                3875 non-null   category
#  20  2ND_PV_BIOLOGY                                3875 non-null   category
#  21  3RD_PV_BIOLOGY                                3875 non-null   category
#  22  4TH_PV_BIOLOGY                                3875 non-null   category
#  23  5TH_PV_BIOLOGY                                3875 non-null   category
#  24  1ST_PV_CHEMISTRY                              3875 non-null   category
#  25  2ND_PV_CHEMISTRY                              3875 non-null   category
#  26  3RD_PV_CHEMISTRY                              3875 non-null   category
#  27  4TH_PV_CHEMISTRY                              3875 non-null   category
#  28  5TH_PV_CHEMISTRY                              3875 non-null   category
#  29  1ST_PV_PHYSICS                                3875 non-null   category
#  30  2ND_PV PHYSICS                                3875 non-null   category
#  31  3RD_PV_PHYSICS                                3875 non-null   category
#  32  4TH_PV_PHYSICS                                3875 non-null   category
#  33  5TH_PV_PHYSICS                                3875 non-null   category
#  34  1ST_PV_EARTH SCIENCE                          3875 non-null   category
#  35  2ND_PV_EARTH SCIENCE                          3875 non-null   category
#  36  3RD_PV_EARTH SCIENCE                          3875 non-null   category
#  37  4TH_PV_EARTH SCIENCE                          3875 non-null   category
#  38  5TH_PV_EARTH SCIENCE                          3875 non-null   category
#  39  Home_Educational_Resources                    3875 non-null   category
#  40  Students_Sense_of_School_Belonging            3875 non-null   category
#  41  Student_Bullying                              3875 non-null   category
#  42  Students_Like_Learning_Mathematics            3875 non-null   category
#  43  Instructional_Clarity_in_Mathematics_Lessons  3875 non-null   category
#  44  Disorderly_Behavior_during_Math_Lessons       3875 non-null   category
#  45  Students_Confident_in_Mathematics             3875 non-null   category
#  46  Students_Value_Mathematics                    3875 non-null   category
#  47  Students_Like_Learning_Science                3875 non-null   category
#  48  Instructional_Clarity_in_Science_Lessons      3875 non-null   category
#  49  Students_Confident_in_Science                 3875 non-null   category
#  50  Students_Value_Science                        3875 non-null   category
#  51  Digital_Self_Efficacy                         3875 non-null   category
#  52  Disorderly_Behavior_during_Science_Lessons    3875 non-null   category
#  53  Students_Value_Environmental_Preservation     3875 non-null   category
# dtypes: category(54)
# memory usage: 4.5 MB
